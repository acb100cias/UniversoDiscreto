# %%
from numpy import *
import networkx as nx
from matplotlib import pyplot as plt
from netwulf import visualize as vis

# %%
er=nx.erdos_renyi_graph(100,0.01)

# %%
vis(er)
# Out:
# (None, None)

# %%
ws=nx.watts_strogatz_graph(100,10,0.01)

# %%
vis(ws)
# Out:
# (None, None)

# %%
ba=nx.barabasi_albert_graph(100,5)

# %%
vis(ba)
# Out:
# (None, None)

# %%
n=1000
er=nx.erdos_renyi_graph(n,0.01)
ws=nx.watts_strogatz_graph(n,10,0.01)
ba=nx.barabasi_albert_graph(n,5)
plt.figure(figsize=(20,10))
Pker = [float(x) / n for x in nx.degree_histogram(er)]
domain = range(len(Pker))
plt.loglog(domain, Pker, '-', label = 'Erdos-Renyi')
Pkws = [float(x) / n for x in nx.degree_histogram(ws)]
domain = range(len(Pkws))
plt.loglog(domain, Pkws, '--', label = 'Watts-Strogatz')
Pkba = [float(x) / n for x in nx.degree_histogram(ba)]
domain = range(len(Pkba))
plt.loglog(domain, Pkba, ':', label = 'Barabasi-Albert')
plt.legend()

# %%
plt.loglog(domain, Pkba, ':', label = 'Barabasi-Albert')
plt.legend()
