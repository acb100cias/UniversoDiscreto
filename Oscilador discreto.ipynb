# %%
from numpy import *
from matplotlib.pyplot import *

# %%
x0=1
y0=1
a=0.5

# %%
def X(x,y):
    return array([a*x+y,-a*x+y])

# %%
E=[[],[]]

# %%
E[0].append(x0)
E[1].append(y0)

# %%
E
# Out:
# [[1], [1]]

# %%
E[0].append(X(E[0][-1],E[1][-1])[0])

# %%
E[1].append(X(E[0][-1],E[1][-1])[1])

# %%
E[0].append(X(E[0][-1],E[1][-1])[0])

# %%
E[1].append(X(E[0][-1],E[1][-1])[1])

# %% [markdown]
# Oscilador discreto mal implementado. No se actualiza  correctamente la $y_t$

# %%
for i in range(100):
    E[0].append(X(E[0][-1],E[1][-1])[0])
    E[1].append(X(E[0][-1],E[1][-1])[1])
# Out:
# [[1, 1.5], [1, 0.25]]

# %% [markdown]
# Oscilador discreto bien implementado.

# %%
for i in range(100):
    x,y=E[0][-1],E[1][-1]
    xn,yn=X(x,y)
    E[0].append(xn)
    E[1].append(yn)

# %%
plot(E[0],E[1],'o')

# %%
T=arange(101)

# %%
plot(T,E[0],'o-',label=r'$x_t$')
plot(T,E[1],'o-',label=r'$y_t$')
legend()
